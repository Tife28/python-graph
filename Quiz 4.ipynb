# %%
# %matplotlib inline

import matplotlib.pyplot as plt
x=[1*10**9, 1.7*10**12, 2.5*10**12, 3.1*10**12, 3.6*10**12, 4*10**12, 4.4*10**12]
y=[1, 1.7, 2.5, 3.1, 3.6, 4, 4.4] #x10^12
plt.plot(x,y)
plt.title('Graph of Frequency against Voltage')
plt.xlabel('Voltage')
plt.ylabel('Frequency')
plt.show()
